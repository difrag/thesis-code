# %%
# !pip install mygene
# Out:
# Requirement already satisfied: mygene in c:\users\d_f\miniconda3\envs\sc_solo_env\lib\site-packages (3.2.2)
# Requirement already satisfied: biothings-client>=0.2.6 in c:\users\d_f\miniconda3\envs\sc_solo_env\lib\site-packages (from mygene) (0.4.1)
# Requirement already satisfied: httpx>=0.22.0 in c:\users\d_f\miniconda3\envs\sc_solo_env\lib\site-packages (from biothings-client>=0.2.6->mygene) (0.28.1)
# Requirement already satisfied: anyio in c:\users\d_f\miniconda3\envs\sc_solo_env\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (4.9.0)
# Requirement already satisfied: certifi in c:\users\d_f\appdata\roaming\python\python312\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\d_f\miniconda3\envs\sc_solo_env\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (1.0.9)
# Requirement already satisfied: idna in c:\users\d_f\appdata\roaming\python\python312\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\d_f\miniconda3\envs\sc_solo_env\lib\site-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\d_f\miniconda3\envs\sc_solo_env\lib\site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\d_f\appdata\roaming\python\python312\site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene) (4.12.2)

# %%
import scanpy as sc
import pandas as pd
import numpy as np
import mygene
import subprocess, sys
from pathlib import Path


def collapse_duplicate_gene_ids(adata, gid_key="ensembl_id", how="sum"):
    """
    Collapse columns whose `gid_key` (default: Ensembl ID) appears >1 ×.
    Aggregation method:
        how="sum"   – add counts   (recommended for raw UMI matrices)
        how="mean"  – mean counts
        how="first" – keep first column verbatim
    """
    gid = adata.var[gid_key].values
    dup_mask = pd.Series(gid).duplicated(keep=False).to_numpy()
    if not dup_mask.any():
        print("✓ All Ensembl IDs already unique.")
        return adata
    
    print(f"⚠️  Collapsing {dup_mask.sum()} duplicated columns…")
    
    _, inv, counts = np.unique(gid, return_inverse=True, return_counts=True)
    groups = {g: np.where(inv == g)[0] for g in np.where(counts > 1)[0]}
    
    X = adata.X.tocsr()
    keep = np.ones(adata.n_vars, dtype=bool)
    
    for idxs in groups.values():
        keep[idxs[1:]] = False              # drop all but the first
        if how == "sum":
            X[:, idxs[0]] = X[:, idxs].sum(axis=1)
        elif how == "mean":
            X[:, idxs[0]] = X[:, idxs].mean(axis=1)
        # "first": leave X[:, idxs[0]] as-is
    
    adata._inplace_subset_var(keep)         # updates .X and .var in one go
    print(f"✓ Collapsed to {adata.n_vars} unique genes.")
    return adata

# %%
IN_H5AD  = Path("updated_adata_marked_with_doublets.h5ad")   # input file
OUT_H5AD = Path("updated_adata_unique_ensembl.h5ad")                 # will be written

# %%
adata = sc.read_h5ad(IN_H5AD)
adata
# Out:
# AnnData object with n_obs × n_vars = 74453 × 26147
#     obs: 'sample_id', 'region', 'brain_region', 'batch', 'donor_id', 'braak_stage', 'sex', 'age', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'log1p_total_counts_mt', 'n_genes', 'solo_doublet', 'solo_singlet'
#     var: 'gene_ids', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_mean_counts', 'log1p_total_counts', 'n_cells'

# %%
mg          = mygene.MyGeneInfo()
symbols     = adata.var["gene_ids"].astype(str).tolist()

hits = mg.querymany(
    symbols,
    scopes="symbol,alias,ensembl.gene",
    fields="ensembl.gene",
    species="human",
    as_dataframe=True,
    verbose=False
)

ensembl_map = (hits["ensembl.gene"]
               .dropna()
               .explode()
               .astype(str)
               .groupby(level=0).first())        # keep first match per symbol

adata.var["ensembl_id"] = adata.var["gene_ids"].map(ensembl_map) \
                                            .fillna(adata.var["gene_ids"])
print("↳  Example mapping:")
adata.var[["gene_ids", "ensembl_id"]].head()
# Out:
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# ↳  Example mapping:
#                       gene_ids       ensembl_id
# RP11-34P13.7   ENSG00000238009  ENSG00000238009
# FO538757.2     ENSG00000279457  ENSG00000279457
# AP006222.2     ENSG00000228463  ENSG00000228463
# RP4-669L17.10  ENSG00000237094  ENSG00000237094
# RP5-857K21.4   ENSG00000230021  ENSG00000230021

# %%
adata = collapse_duplicate_gene_ids(adata, gid_key="ensembl_id", how="sum")

# Make the official gene column the now-unique Ensembl IDs
adata.var["gene_ids"] = adata.var["ensembl_id"]
adata.var.drop(columns=["ensembl_id"], inplace=True)
# Out:
# ✓ All Ensembl IDs already unique.

# %%
adata.write(OUT_H5AD)
print(f"✔️  Saved cleaned file → {OUT_H5AD}")
# Out:
# ✔️  Saved cleaned file → updated_adata_unique_ensembl.h5ad

# %%
result_path, has_warnings = validate_h5ad(
    input_path=str(OUT_H5AD),
    output_path=None,          # write next to input; change if you want
    log_level="INFO"
)
print("Validator wrote:", result_path)
print("Had warnings?  ", has_warnings)

# %%
import scanpy as sc, pandas as pd, numpy as np
from mygene import MyGeneInfo        # pip install mygene

adata = sc.read_h5ad(IN_H5AD)

# 1. Map your current var.index → Ensembl IDs
mg   = MyGeneInfo()
conv = mg.querymany(adata.var_names.tolist(),
                    scopes="symbol,ensemblgene,entrezgene",
                    fields="ensembl.gene",
                    species="human", as_dataframe=True)

# Build a mapping dict {old_id → ensembl_id}
id_map = (conv["ensembl.gene"]
          .dropna()
          .apply(lambda x: x[0] if isinstance(x, list) else x)
          .to_dict())
adata.var["ensembl_id"] = adata.var_names.map(id_map)

# 2. Keep genes we could map and make them unique
adata = adata[:, adata.var["ensembl_id"].notna()].copy()
dupes = adata.var["ensembl_id"].duplicated(keep=False)

# optional: collapse duplicates by summing counts
for gid in adata.var.loc[dupes, "ensembl_id"].unique():
    cols = np.where(adata.var["ensembl_id"] == gid)[0]
    newX = adata.X[:, cols].sum(axis=1)
    adata.X[:, cols[0]] = newX          # put sum in first column
    adata.X = adata.X[:, ~np.isin(range(adata.n_vars), cols[1:])]  # drop others

# 3. Finalise
adata.var_names    = adata.var["ensembl_id"]      # enforce uniqueness
adata.var.index    = adata.var_names
adata.write_h5ad("for_MapMyCells.h5ad", compression="gzip")
# Out:
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 414 input query terms found dup hits:	[('LINC01346', 2), ('LINC01141', 2), ('LINC01355', 3), ('LINC01226', 2), ('NFYC-AS1', 2), ('KDM4A-AS
# 8491 input query terms found no hit:	['RP11-34P13.7', 'FO538757.2', 'AP006222.2', 'RP4-669L17.10', 'RP5-857K21.4', 'RP5-857K21.2', 'RP11-

# %%
import scanpy as sc, pandas as pd, numpy as np
adata = sc.read_h5ad("updated_adata_marked_with_doublets.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 74453 × 26147
#     obs: 'sample_id', 'region', 'brain_region', 'batch', 'donor_id', 'braak_stage', 'sex', 'age', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'log1p_total_counts_mt', 'n_genes', 'solo_doublet', 'solo_singlet'
#     var: 'gene_ids', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_mean_counts', 'log1p_total_counts', 'n_cells'

# %%
adata.obs
# Out:
#                                                      sample_id  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...  GSM4432645
# ...                                                        ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  GSM4432654
#
#                                                                region  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...  Entorhinal cortex
# ...                                                               ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  Entorhinal cortex
#
#                                                          brain_region batch  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...  Entorhinal cortex     C
# ...                                                               ...   ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  Entorhinal cortex     D
#
#                                                     donor_id  braak_stage  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...         2            0
# ...                                                      ...          ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...        10            6
#
#                                                      sex  age  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...  Male   60
# ...                                                  ...  ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  Male   82
#
#                                                     n_genes_by_counts  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...               4620
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...               2562
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...                484
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                244
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...               3068
# ...                                                               ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                292
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                498
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                392
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                470
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...               1423
#
#                                                     total_counts  ...  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...       11301.0  ...
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...        4558.0  ...
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...         634.0  ...
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...         305.0  ...
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...        6162.0  ...
# ...                                                          ...  ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...         363.0  ...
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...         698.0  ...
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...         443.0  ...
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...         600.0  ...
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...        2334.0  ...
#
#                                                     log1p_n_genes_by_counts  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...                 8.438366
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                 7.848934
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...                 6.184149
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                 5.501258
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...                 8.029433
# ...                                                                     ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                 5.680173
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                 6.212606
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                 5.976351
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                 6.154858
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                 7.261927
#
#                                                     log1p_total_counts  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...            9.332735
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...            8.424859
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...            6.453625
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...            5.723585
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...            8.726481
# ...                                                                ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...            5.897154
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...            6.549651
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...            6.098074
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...            6.398595
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...            7.756196
#
#                                                     pct_counts_in_top_50_genes  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...                   19.653128
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                   19.197016
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...                   29.179811
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                   36.393443
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...                   18.822002
# ...                                                                        ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                   33.333333
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                   33.524355
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                   22.747748
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                   27.166667
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                   26.252677
#
#                                                     pct_counts_in_top_100_genes  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...                    25.546412
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                    25.756911
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...                    39.432177
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                    52.786885
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...                    25.799124
# ...                                                                         ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                    47.107438
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                    42.979943
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                    34.009009
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                    38.333333
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                    33.147752
#
#                                                     pct_counts_in_top_200_genes  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...                    32.952836
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                    34.510750
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...                    55.205047
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                    85.573770
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...                    34.252799
# ...                                                                         ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                    74.655647
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                    57.306590
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                    56.531532
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                    55.000000
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                    42.612420
#
#                                                     pct_counts_in_top_500_genes  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...                    46.243695
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                    49.846424
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...                   100.000000
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                   100.000000
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...                    50.024339
# ...                                                                         ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                    60.428266
#
#                                                     log1p_total_counts_mt  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...               6.746412
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...               2.890372
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...               3.761200
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...               3.091043
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...               5.267858
# ...                                                                   ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...               1.791759
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...               1.386294
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...               1.945910
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...               3.713572
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...               3.465736
#
#                                                     n_genes  solo_doublet  \
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...     4620          True
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...     2562         False
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...      484          True
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...      244         False
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...     3069          True
# ...                                                     ...           ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...      292         False
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...      498         False
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...      393         False
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...      470         False
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...     1424         False
#
#                                                     solo_singlet
# GSM4432645_GSM4432645_AAACCTGAGGATGCGT-1_GSM443...      0.199106
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...      0.289714
# GSM4432645_GSM4432645_AAACCTGCAAGTAGTA-1_GSM443...      0.158051
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...      0.975610
# GSM4432645_GSM4432645_AAACCTGCATACTCTT-1_GSM443...      0.235072
# ...                                                          ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...      0.994819
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...      0.830773
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...      0.838007
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...      0.773198
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...      0.506192
#
# [74453 rows x 22 columns]

# %%
adata.var
# Out:
#                       gene_ids     mt  n_cells_by_counts  mean_counts  \
# RP11-34P13.7   ENSG00000238009  False                336     0.004064
# FO538757.2     ENSG00000279457  False               8310     0.118416
# AP006222.2     ENSG00000228463  False               1789     0.022722
# RP4-669L17.10  ENSG00000237094  False                712     0.008881
# RP5-857K21.4   ENSG00000230021  False              13117     0.226731
# ...                        ...    ...                ...          ...
# AC007325.2     ENSG00000277196  False                531     0.006586
# BX072566.1     ENSG00000277630  False                 14     0.000167
# AL354822.1     ENSG00000278384  False                349     0.004339
# AC004556.1     ENSG00000276345  False                 18     0.000215
# AC240274.1     ENSG00000271254  False                714     0.008749
#
#                pct_dropout_by_counts  total_counts  log1p_mean_counts  \
# RP11-34P13.7               99.598389         340.0           0.000104
# FO538757.2                 90.067294        9907.0           0.004658
# AP006222.2                 97.861659        1901.0           0.000816
# RP4-669L17.10              99.148967         743.0           0.000245
# RP5-857K21.4               84.321624       18969.0           0.006836
# ...                              ...           ...                ...
# AC007325.2                 99.365311         551.0           0.000175
# BX072566.1                 99.983266          14.0           0.000004
# AL354822.1                 99.582850         363.0           0.000112
# AC004556.1                 99.978485          18.0           0.000020
# AC240274.1                 99.146576         732.0           0.000230
#
#                log1p_total_counts  n_cells
# RP11-34P13.7             6.047372      336
# FO538757.2               9.846230     8310
# AP006222.2               8.102889     1789
# RP4-669L17.10            6.899723      712
# RP5-857K21.4            10.230955    13117
# ...                           ...      ...
# AC007325.2               6.561031      531
# BX072566.1               2.772589       14
# AL354822.1               6.115892      349
# AC004556.1               4.418840       18
# AC240274.1               6.837333      714
#
# [26147 rows x 9 columns]

# %%
adata = adata[~adata.obs["solo_doublet"]].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 64086 × 26147
#     obs: 'sample_id', 'region', 'brain_region', 'batch', 'donor_id', 'braak_stage', 'sex', 'age', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'log1p_total_counts_mt', 'n_genes', 'solo_doublet', 'solo_singlet'
#     var: 'gene_ids', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_mean_counts', 'log1p_total_counts', 'n_cells'

# %%
# ------------------------------------------------------------
# Clean an .h5ad file so Map My Cells accepts it
# ------------------------------------------------------------
#  1) maps every gene symbol/alias ➜ canonical Ensembl ID
#  2) keeps only genes that could be mapped
#  3) drops any duplicate Ensembl IDs (keeps the first one)
#  4) writes a fresh .h5ad file with unique Ensembl IDs
#
#  Works for human or mouse data.
# ------------------------------------------------------------
#  ❗ Adjust only the three parameters just below
# ------------------------------------------------------------
in_file   = "up_no_doublets.h5ad"   # ← your current file
out_file  = "up_clean_unique.h5ad"  # ← file to upload
species   = "human"                 # "human" or "mouse"
# ------------------------------------------------------------

# If you haven’t already, install prerequisites right here:
# !pip install scanpy mygene --quiet

import scanpy as sc
import pandas as pd
from mygene import MyGeneInfo

print(f"▶ loading {in_file}")


# ------------------------------------------------------------------
# 1. Build a mapping: gene_symbol/alias → canonical Ensembl gene ID
# ------------------------------------------------------------------
mg = MyGeneInfo()
symbol_list = adata.var_names.tolist()
sym2ens = {}

# mygene can take up to 1 000 queries at once, so chunk the list
for start in range(0, len(symbol_list), 1000):
    chunk = symbol_list[start : start + 1000]
    for hit in mg.querymany(chunk,
                            scopes=["symbol", "alias", "name"],
                            fields="ensembl.gene",
                            species=species,
                            as_dataframe=False):
        if hit.get("notfound"):
            continue
        ens_field = hit["ensembl"]
        if isinstance(ens_field, list):
            ens_field = ens_field[0]
        ens_id = ens_field["gene"].split(".")[0]      # strip version suffix
        sym2ens[hit["query"]] = ens_id

print(f"  ↳ mapped {len(sym2ens):,} of {adata.n_vars:,} genes")

# ------------------------------------------------------------------
# 2. Keep only successfully-mapped genes
# ------------------------------------------------------------------
keep_mask = adata.var_names.isin(sym2ens)
adata = adata[:, keep_mask].copy()
adata.var["ensembl_id"] = adata.var_names.map(sym2ens)

# ------------------------------------------------------------------
# 3. Drop duplicate Ensembl IDs (keep the first)
# ------------------------------------------------------------------
dup_mask = adata.var["ensembl_id"].duplicated(keep="first")
n_dups   = dup_mask.sum()
if n_dups:
    print(f"  ↳ found {n_dups:,} duplicate Ensembl IDs — dropping extras")
    adata = adata[:, ~dup_mask].copy()

# Set the Ensembl IDs as the final, unique var index
adata.var_names = adata.var["ensembl_id"]
adata.var_names_make_unique()

# ------------------------------------------------------------------
# 4. Save
# ------------------------------------------------------------------
adata.write(out_file)
print(f"✔ cleaned file written to {out_file}")
# Out:
# Input sequence provided is already in string format. No operation performed
# ▶ loading up_no_doublets.h5ad
# 258 input query terms found dup hits:	[('TTLL10', 2), ('DVL1', 2), ('MRPL20', 4), ('ANKRD65', 3), ('SSU72', 10), ('SLC35E2', 2), ('GNB1',
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 45
#      43 if hit.get("notfound"):
#      44     continue
# ---> 45 ens_field = hit["ensembl"]
#      46 if isinstance(ens_field, list):
#      47     ens_field = ens_field[0]
#
# KeyError: 'ensembl'

# %%
adata.var
# Out:
#                       gene_ids     mt  n_cells_by_counts  mean_counts  \
# RP11-34P13.7   ENSG00000238009  False                336     0.004064
# FO538757.2     ENSG00000279457  False               8310     0.118416
# AP006222.2     ENSG00000228463  False               1789     0.022722
# RP4-669L17.10  ENSG00000237094  False                712     0.008881
# RP5-857K21.4   ENSG00000230021  False              13117     0.226731
# ...                        ...    ...                ...          ...
# AC007325.2     ENSG00000277196  False                531     0.006586
# BX072566.1     ENSG00000277630  False                 14     0.000167
# AL354822.1     ENSG00000278384  False                349     0.004339
# AC004556.1     ENSG00000276345  False                 18     0.000215
# AC240274.1     ENSG00000271254  False                714     0.008749
#
#                pct_dropout_by_counts  total_counts  log1p_mean_counts  \
# RP11-34P13.7               99.598389         340.0           0.000104
# FO538757.2                 90.067294        9907.0           0.004658
# AP006222.2                 97.861659        1901.0           0.000816
# RP4-669L17.10              99.148967         743.0           0.000245
# RP5-857K21.4               84.321624       18969.0           0.006836
# ...                              ...           ...                ...
# AC007325.2                 99.365311         551.0           0.000175
# BX072566.1                 99.983266          14.0           0.000004
# AL354822.1                 99.582850         363.0           0.000112
# AC004556.1                 99.978485          18.0           0.000020
# AC240274.1                 99.146576         732.0           0.000230
#
#                log1p_total_counts  n_cells
# RP11-34P13.7             6.047372      336
# FO538757.2               9.846230     8310
# AP006222.2               8.102889     1789
# RP4-669L17.10            6.899723      712
# RP5-857K21.4            10.230955    13117
# ...                           ...      ...
# AC007325.2               6.561031      531
# BX072566.1               2.772589       14
# AL354822.1               6.115892      349
# AC004556.1               4.418840       18
# AC240274.1               6.837333      714
#
# [26147 rows x 9 columns]

# %%
adata.obs
# Out:
#                                                      sample_id  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...  GSM4432645
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...  GSM4432645
# ...                                                        ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  GSM4432654
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  GSM4432654
#
#                                                                region  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...  Entorhinal cortex
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...  Entorhinal cortex
# ...                                                               ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  Entorhinal cortex
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  Entorhinal cortex
#
#                                                          brain_region batch  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...  Entorhinal cortex     C
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...  Entorhinal cortex     C
# ...                                                               ...   ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  Entorhinal cortex     D
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  Entorhinal cortex     D
#
#                                                     donor_id  braak_stage  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...         2            0
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...         2            0
# ...                                                      ...          ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...        10            6
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...        10            6
#
#                                                      sex  age  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...  Male   60
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...  Male   60
# ...                                                  ...  ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...  Male   82
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...  Male   82
#
#                                                     n_genes_by_counts  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...               2562
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                244
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...                229
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...                317
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...                376
# ...                                                               ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                292
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                498
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                392
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                470
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...               1423
#
#                                                     total_counts  ...  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...        4558.0  ...
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...         305.0  ...
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...         271.0  ...
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...         372.0  ...
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...         479.0  ...
# ...                                                          ...  ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...         363.0  ...
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...         698.0  ...
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...         443.0  ...
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...         600.0  ...
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...        2334.0  ...
#
#                                                     log1p_n_genes_by_counts  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                 7.848934
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                 5.501258
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...                 5.438079
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...                 5.762051
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...                 5.932245
# ...                                                                     ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                 5.680173
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                 6.212606
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                 5.976351
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                 6.154858
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                 7.261927
#
#                                                     log1p_total_counts  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...            8.424859
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...            5.723585
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...            5.605802
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...            5.921578
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...            6.173786
# ...                                                                ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...            5.897154
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...            6.549651
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...            6.098074
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...            6.398595
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...            7.756196
#
#                                                     pct_counts_in_top_50_genes  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                   19.197016
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                   36.393443
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...                   33.948339
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...                   28.225806
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...                   31.941545
# ...                                                                        ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                   33.333333
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                   33.524355
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                   22.747748
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                   27.166667
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                   26.252677
#
#                                                     pct_counts_in_top_100_genes  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                    25.756911
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                    52.786885
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...                    52.398524
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...                    41.666667
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...                    42.379958
# ...                                                                         ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                    47.107438
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                    42.979943
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                    34.009009
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                    38.333333
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                    33.147752
#
#                                                     pct_counts_in_top_200_genes  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                    34.510750
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                    85.573770
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...                    89.298893
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...                    68.548387
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...                    63.256785
# ...                                                                         ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                    74.655647
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                    57.306590
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                    56.531532
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                    55.000000
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                    42.612420
#
#                                                     pct_counts_in_top_500_genes  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...                    49.846424
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...                   100.000000
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...                   100.000000
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...                   100.000000
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...                   100.000000
# ...                                                                         ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...                   100.000000
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...                    60.428266
#
#                                                     log1p_total_counts_mt  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...               2.890372
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...               3.091043
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...               2.944439
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...               2.079442
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...               2.639057
# ...                                                                   ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...               1.791759
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...               1.386294
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...               1.945910
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...               3.713572
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...               3.465736
#
#                                                     n_genes  solo_doublet  \
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...     2562         False
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...      244         False
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...      229         False
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...      317         False
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...      376         False
# ...                                                     ...           ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...      292         False
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...      498         False
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...      393         False
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...      470         False
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...     1424         False
#
#                                                     solo_singlet
# GSM4432645_GSM4432645_AAACCTGAGTCAATAG-1_GSM443...      0.289714
# GSM4432645_GSM4432645_AAACCTGCAGACGTAG-1_GSM443...      0.975610
# GSM4432645_GSM4432645_AAACCTGGTGAGTATA-1_GSM443...      0.990093
# GSM4432645_GSM4432645_AAACCTGGTTATCACG-1_GSM443...      0.987308
# GSM4432645_GSM4432645_AAACCTGTCAAGCCTA-1_GSM443...      0.434747
# ...                                                          ...
# GSM4432654_GSM4432654_TTTGTCATCCACGTGG-1_GSM443...      0.994819
# GSM4432654_GSM4432654_TTTGTCATCGCGGATC-1_GSM443...      0.830773
# GSM4432654_GSM4432654_TTTGTCATCTATCGCC-1_GSM443...      0.838007
# GSM4432654_GSM4432654_TTTGTCATCTCGCTTG-1_GSM443...      0.773198
# GSM4432654_GSM4432654_TTTGTCATCTCTGCTG-1_GSM443...      0.506192
#
# [64086 rows x 22 columns]

# %%
# --- Move Ensembl IDs into the index ---------------------------------
adata.var["gene_symbol"] = adata.var_names      # keep symbols as a column
adata.var_names = adata.var["gene_ids"]         # set index = Ensembl IDs
adata.var_names_make_unique()                   # be 100 % sure they’re unique

# --- Sanity checks ----------------------------------------------------
assert adata.var_names.is_unique
assert adata.var_names.str.startswith("ENS").all()

# (optional) if you no longer need the old column
#adata.var.drop(columns=["gene_ids"], inplace=True)

# --- Save -------------------------------------------------------------
adata.write("ready_for_mapmycells.h5ad")
print("✅ File saved: ready_for_mapmycells.h5ad — upload this to Map My Cells.")
# Out:
# ✅ File saved: ready_for_mapmycells.h5ad — upload this to Map My Cells.
